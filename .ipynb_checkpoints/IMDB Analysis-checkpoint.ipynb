# %% [markdown]
# # How much disk space does one need to store all relevant movies since the year 2000?
#
# ## Assumptions:
# * Netflix uses 13 MB for one minute of video
# * 1024 MB are in a GB
# * 1024 GB are in a TB
# * Relevant movies are the movies that account for 80% of votes on IMDB
# * AND are released after the year 2000.

# %%
# We want inline charts
# %matplotlib inline

import pandas as pd # For data management
import numpy as np # For math and array functions
import matplotlib.pyplot as plt # For plotting

# %%
# Read movies file
movies = pd.read_csv('basics.tsv', sep='\t', index_col='tconst', low_memory=False)

# %%
list(movies)
# Out:
# ['titleType',
#  'primaryTitle',
#  'originalTitle',
#  'isAdult',
#  'startYear',
#  'endYear',
#  'runtimeMinutes',
#  'genres']

# %%
movies.values[1]
# Out:
# array(['short', 'Le clown et ses chiens', 'Le clown et ses chiens', 0,
#        '1892', '\\N', '5', 'Animation,Short'], dtype=object)

# %%
# runtime should be a number
movies[['runtimeMinutes']] = movies[['runtimeMinutes']].apply(pd.to_numeric, errors='coerce')

# Set start year to be a number
movies[['startYear']] = movies[['startYear']].apply(pd.to_numeric, errors='coerce')

# %%
movies.values[1]
# Out:
# array(['short', 'Le clown et ses chiens', 'Le clown et ses chiens', 0,
#        1892.0, '\\N', 5.0, 'Animation,Short'], dtype=object)

# %%
# load the ratings file
ratings = pd.read_csv('ratings.tsv', sep='\t', index_col='tconst', low_memory=False)

# %%
list(ratings)
# Out:
# ['averageRating', 'numVotes']

# %%
ratings.values[1]
# Out:
# array([   6.5,  156. ])

# %%
# Add the ratings to the movies
movies = pd.merge(movies, ratings, left_index=True, right_index=True)

# %%
# Dropping NANs
tmp = movies.dropna(axis=0, how='any')
dropped = movies.size - tmp.size
movies = tmp
dropped
# Out:
# 2323560

# %%
movies
# Out:
#               titleType                                       primaryTitle  \
# tconst
# tt0000001         short                                         Carmencita
# tt0000002         short                             Le clown et ses chiens
# tt0000003         short                                     Pauvre Pierrot
# tt0000005         short                                   Blacksmith Scene
# tt0000006         short                                  Chinese Opium Den
# tt0000007         short        Corbett and Courtney Before the Kinetograph
# tt0000008         short             Edison Kinetoscopic Record of a Sneeze
# tt0000009         movie                                         Miss Jerry
# tt0000010         short              Employees Leaving the Lumière Factory
# tt0000011         short                            Akrobatisches Potpourri
# tt0000012         short                             The Arrival of a Train
# tt0000013         short        The Photographical Congress Arrives in Lyon
# tt0000014         short                      Tables Turned on the Gardener
# tt0000015         short                                Autour d'une cabine
# tt0000016         short                             Barque sortant du port
# tt0000017         short                           Italienischer Bauerntanz
# tt0000018         short                               Das boxende Känguruh
# tt0000020         short                                     The Derby 1895
# tt0000022         short                                   Blacksmith Scene
# tt0000023         short                                            The Sea
# tt0000026         short                      The Messers. Lumière at Cards
# tt0000027         short                         Cordeliers' Square in Lyon
# tt0000028         short                               Fishing for Goldfish
# tt0000029         short                                      Baby's Dinner
# tt0000030         short                                 Rough Sea at Dover
# tt0000031         short                                Jumping the Blanket
# tt0000032         short                              Die Serpentintänzerin
# tt0000033         short                                       Trick Riding
# tt0000036         short                                   Awakening of Rip
# tt0000041         short                                  Bataille de neige
# ...                 ...                                                ...
# tt7881834         short                                               Gwen
# tt7881954         movie                           Grazinti Nepriklausomybe
# tt7882108         video  Alpha Waves Music Binaural Beats: Relaxing Mus...
# tt7882184         video  Amazing Coral Reef Nature: Relaxing Undersea A...
# tt7901246     2018.0      \N           110.0               Documentary
# tt7901362     2017.0      \N            61.0               Documentary
# tt7901758     2018.0      \N            15.0            Short,Thriller
# tt7902184     2018.0      \N            65.0                    Comedy
# tt7903142     2018.0      \N             9.0                     Short
# tt7906072     1947.0      \N            12.0             Fantasy,Short
# tt7906798     2017.0      \N            10.0             Mystery,Short
# tt7908752     2018.0      \N             4.0              Comedy,Short
# tt7909924     2017.0      \N            91.0               Crime,Drama
# tt7913346     2017.0      \N            35.0  Comedy,Documentary,Short
#
#            averageRating  numVotes
# tconst
# tt0000001            5.8      1346
# tt0000002            6.5       156
# tt0000003            6.6       927
# tt0000005            6.2      1612
# tt0000006            5.7        79
# tt0000007            5.5       539
# tt0000008            5.6      1437
# tt0000009            5.4        61
# tt0000010            6.9      4821
# tt0000011            5.4       191
# tt0000012            7.4      7959
# tt0000013            5.7      1226
# tt0000014            7.2      3485
# tt0000015            6.2       598
# tt0000016            5.9       903
# tt0000017            4.9       180
# tt0000018            5.5       386
# tt0000020            5.1       216
# tt0000022            5.1       694
# tt0000023            5.7       859
# tt0000026            5.7      1072
# tt0000027            5.6       719
# tt0000028            5.2       659
# tt0000029            5.9      2302
# tt0000030            5.3       552
# tt0000031            5.6       643
# tt0000032            5.3       270
# tt0000033            5.6       682
# tt0000036            4.5       394
# tt0000041            6.7      1117
# ...                  ...       ...
# tt7881834           10.0         6
# tt7881954            6.8       173
# tt7882108            9.0         7
# tt7882184            9.6         7
# tt7882204            9.3         7
# tt7882770            9.7         7
# tt7882956            9.7         7
# tt7884974            8.7         6
# tt7885330           10.0         7
# tt7886882            9.4         5
# tt7886884            9.1         7
# tt7889586            9.6         8
# tt7889682            7.1        10
# tt7890456           10.0         7
# tt7890672            9.9         7
# tt7893992            8.0         5
# tt7896164           10.0         8
# tt7897088            9.2        21
# tt7897560            3.1         9
# tt7900936            7.1         7
# tt7901246            9.0         9
# tt7901362            9.9        28
# tt7901758            8.6         7
# tt7902184            5.0        38
# tt7903142            8.2         5
# tt7906072            5.8         5
# tt7906798            9.8         5
# tt7908752           10.0         5
# tt7909924            7.1        11
# tt7913346            7.0         8
#
# [567881 rows x 10 columns]

# %%
# What is the average number of votes per movie?
avgNumVotes = movies['numVotes'].mean()
avgNumVotes
# Out:
# 1379.8699463443925

# %%
# Sort movies that the most popular are on top
movies = movies.sort(['numVotes'],  ascending=False)

# Get the number of all ratings
allRatings = movies['numVotes'].sum()
seenRatings = 0

# Set all movies as irrelevant
movies['relevant'] = False
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app

# %%
# Go through all movies until you have seen 80% of all ratings
# The movies that account for 80% of votes are relevant

for index, movie in movies.iterrows():
    movies.loc[index, 'relevant'] = True
    seenRatings += movie['numVotes']
    if seenRatings / allRatings >= 0.8:
        break

# %%
# How many percent of the movies do account for 80% of votes
movies[movies['relevant']].size / movies.size * 100
# Out:
# 1.2620601851444229

# %%
# Get movies that are new and relevant
newAndRelevant = movies[((movies['relevant'] == True) & (movies['startYear'] > 2000) & (movies['titleType'] == "movie"))]
newAndRelevant.size
# Out:
# 41536

# %%
# Netflix uses 13mb for one minute of video
# 1024 mb in a gb
# 1024 gb in a tb
print (str(newAndRelevant['runtimeMinutes'].sum() * 13 / 1024 / 1024) + " tb")
# Out:
# 5.107929229736328 tb

# %% [markdown]
# # One would need 5.1 TB to store all relevant movies since the year 2000
